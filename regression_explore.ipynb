# %%
from env import get_connection
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
from math import sqrt
from scipy import stats
from scipy.stats import pearsonr, spearmanr
import wrangle as w

# ignore warnings
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split

# %%
df= pd.read_csv('zillow.csv')
df.drop(columns= ['Unnamed: 0'], inplace= True)
df.head()
# Out:
#    yearbuilt  taxvaluedollarcnt  taxamount  bedroomcnt  bathroomcnt  \
# 0        NaN            27516.0        NaN         0.0          0.0
# 1        NaN               10.0        NaN         0.0          0.0
# 2        NaN               10.0        NaN         0.0          0.0
# 3        NaN             2108.0     174.21         0.0          0.0
# 4     2005.0           296425.0    6941.39         4.0          2.0
#
#    calculatedfinishedsquarefeet    fips
# 0                           NaN  6037.0
# 1                           NaN  6037.0
# 2                           NaN  6037.0
# 3                           NaN  6037.0
# 4                        3633.0  6037.0

# %%
train, val, test= w.wrangle_zillow()
train.shape, val.shape, test.shape,
# Out:
# ((1198531, 8), (513657, 8), (428047, 8))

# %%
train.head()
# Out:
#          Unnamed: 0  year_built  tax_value  taxamount  bedrooms  bathrooms  \
# 1567873     1567873      1950.0   191578.0    2712.21       3.0        1.0
# 1218138     1218138      1950.0  1345206.0   16539.04       2.0        2.0
# 339661       339661      1953.0   356648.0    4575.16       2.0        1.0
# 1017133     1017133      1946.0   175069.0    2635.51       3.0        2.0
# 40250         40250      1957.0   543000.0    6344.96       3.0        2.0
#
#            area    fips
# 1567873  1248.0  6037.0
# 1218138  1326.0  6037.0
# 339661   1053.0  6037.0
# 1017133  1256.0  6037.0
# 40250    1640.0  6059.0

# %% [markdown]
# # Regression Explore Exercises

# %% [markdown]
# 3. Write a function named plot_variable_pairs that accepts a dataframe as input and plots all of the pairwise relationships along with the regression line for each pair.

# %%
df.drop(columns= ['fips'], inplace= True)

# %%
def plot_variable_pairs(train):
    '''takes in the dataframe and plots all the pairwise relationships and includes a regression line'''
    
    sns.pairplot(data=df.sample(2000),kind='reg',plot_kws={'line_kws':{'color':'firebrick'}}, corner=True)
    plt.show()

# %%
plot_variable_pairs(df)

# %% [markdown]
# 4. Write a function named plot_categorical_and_continuous_vars that accepts your dataframe and the name of the columns that hold the continuous and categorical features and outputs 3 different plots for visualizing a categorical variable and a continuous variable.

# %%
train.drop(columns= ['Unnamed: 0'], inplace= True)

# %%
train.head(1)
# Out:
#          year_built  tax_value  taxamount  bedrooms  bathrooms    area    fips
# 1567873      1950.0   191578.0    2712.21       3.0        1.0  1248.0  6037.0

# %%
cat= ['fips']
con= ['year_built', 'tax_value', 'taxamount', 'bedrooms', 'bathrooms', 'area']

# %%
def plot_catagorical_and_continous_vars(df, cat, con):
    sns.stripplot()
    plt.show()
    sns.boxplot(data= df.sample(2000), x= cat, y= con)
    plt.show()
    sns.catplot(data= df.sample(2000), x= cat, y= con)

# %%
def plot_catagorical_and_continous_vars(df, cat, con):
    '''takes in dataframe, followed by cat value then con value to compare a catagorical and continous variable threed different ways
    stripplot, boxplot, and catplot'''
    sns.stripplot(data=df, x=cat, y=con)
    plt.show()
    sns.boxplot(data=df, x=cat, y=con)
    plt.show()
    sns.catplot(data=df, x=cat, y=con)
    plt.show()

# %%
plot_catagorical_and_continous_vars(train, cat, con)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [45], in <cell line: 1>()
# ----> 1 plot_catagorical_and_continous_vars(train, cat, con)
#
# Input In [44], in plot_catagorical_and_continous_vars(df, cat, con)
#       1 def plot_catagorical_and_continous_vars(df, cat, con):
#       2     '''takes in dataframe, followed by cat value then con value to compare a catagorical and continous variable threed different ways
#       3     stripplot, boxplot, and catplot'''
# ----> 4     sns.stripplot(data=df, x=cat, y=con)
#       5     plt.show()
#       6     sns.boxplot(data=df, x=cat, y=con)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
# ...

# %% [markdown]
# 5. Save the functions you have written to create visualizations in your explore.py file. Rewrite your notebook code so that you are using the functions imported from this file.

# %% [markdown]
# 6. Use the functions you created above to explore your Zillow train dataset in your explore.ipynb notebook.

# %% [markdown]
# 7. Come up with some initial hypotheses based on your goal of predicting property value.

# %%
train.head(1)

# %% [markdown]
# NULL HYPOTHESIS: There is no a relationship between property value and the year it was built (year_built)
#
#
# ALTERNATIVE HYPOTHESIS: There is a relationship between property value and the year it was built (year_built)

# %% [markdown]
# 8. Visualize all combinations of variables in some way.

# %%
train.head(1)
# Out:
#          year_built  tax_value  taxamount  bedrooms  bathrooms    area    fips
# 1567873      1950.0   191578.0    2712.21       3.0        1.0  1248.0  6037.0

# %%
zill_corr= train.drop(columns=['tax_value']).corr()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(zill_corr, cmap='Blues', annot=True, linewidth=0.5)
plt.ylim(0, 4)

plt.show()

# %% [markdown]
# 9. Run the appropriate statistical tests where needed.

# %% [markdown]
# 10. What independent variables are correlated with the dependent variable, home value?

# %% [markdown]
# 11. Which independent variables are correlated with other independent variables (bedrooms, bathrooms, year built, square feet)?

# %% [markdown]
# 12. Make sure to document your takeaways from visualizations and statistical tests as well as the decisions you make throughout your process.

# %% [markdown]
# 13. Explore your dataset with any other visualizations you think will be helpful.
